# %%
# 7.1 Handling Missing Data

# %%
# for data with float64 dtype, pandas uses the floating-point value NaN (Not a Number) to represent misssing data
# this is called  asentienl value; when present, it indicates a missing (or null) value
import pandas as pd
import numpy as np

float_data = pd.Series([1.2,-3.5,np.nan,0])
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
# .isna() gives a Boolean Series of result; null = TRUE
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
# as alternative to 'NA', a built-in 'None' (case-sensitive) value is also used
string_data = pd.Series(["aardvark",np.nan,None,"avocado"])
string_data
# Out:
# 0    aardvark
# 1         NaN
# 2        None
# 3     avocado
# dtype: object

# %%
string_data.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.Series([1,2,None],dtype='float64')
float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
# NA handling object methods
# .dropna() : filter axis labels based on whether values for eahc label have missing data
#          with varying thresholds for how much missing data to tolerate
# .fillna() : fill in missing data with some value or using an interpolation method such as "ffill" or "bfill"
# .isna() : return Boolean values indicating which values are missing/NA
# .notna() : negation of isna, returns True for non-NA values and False for NA values

# %%
# Filtering Out Missing Data

# %%
# using .dropna() in Series
data = pd.Series([1,np.nan,3.5,np.nan,7])
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
# another way to filter out missing data in Series
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
# removing missing data in DataFrames - either drop rows or columns that are all NA, or only dropping rows or columns containing any NA
# .dropna() by default drops any row containing a missing value
data = pd.DataFrame([[1,6.5,3.],[1.,np.nan,np.nan],
                     [np.nan,np.nan,np.nan],[np.nan,6.5,3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# drops all the rows containing any NA
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
# passing how = "all" will drop only rows that are all NA
data.dropna(how="all")

# these functions don't modify the original object, just creates a new object
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
# to drop columns containing NA, pass the argument axis = "columns"
data[4] = np.nan
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis="columns",how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
# only keeping rows contianing at most a certain number of missing observations
# indicate this with the thresh argument
df = pd.DataFrame(np.random.standard_normal((7,3)))
df
# Out:
#           0         1         2
# 0  1.727987  1.236485  0.520799
# 1  0.642867  0.817818  0.852358
# 2  1.282048 -0.682954 -0.721350
# 3 -0.303480  0.837944 -1.144744
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
df.iloc[:4,1] = np.nan
df.iloc[:2,2] = np.nan
df
# Out:
#           0         1         2
# 0  1.727987       NaN       NaN
# 1  0.642867       NaN       NaN
# 2  1.282048       NaN -0.721350
# 3 -0.303480       NaN -1.144744
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
df.dropna()
# Out:
#           0         1         2
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
# using argument thresh
df.dropna(thresh=2)
# thresh = 2 means non-NaN threshold is 2 (at least 2 non-NaN values), if threshold not met, drop
# thresh = N means the row needs N "votes" to stay in the DataFrame
# Out:
#           0         1         2
# 2  1.282048       NaN -0.721350
# 3 -0.303480       NaN -1.144744
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
# Filling In Missing Data

# %%
# .fillna() : filling NaN with a constant
df.fillna(0)
# Out:
#           0         1         2
# 0  1.727987  0.000000  0.000000
# 1  0.642867  0.000000  0.000000
# 2  1.282048  0.000000 -0.721350
# 3 -0.303480  0.000000 -1.144744
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
# using fillna() with a dictioinary, can use a different fill value for each column
df.fillna({1:0.5,2:0})
# Out:
#           0         1         2
# 0  1.727987  0.500000  0.000000
# 1  0.642867  0.500000  0.000000
# 2  1.282048  0.500000 -0.721350
# 3 -0.303480  0.500000 -1.144744
# 4  0.026633 -0.603445 -0.306248
# 5  1.096901  0.309833  0.014388
# 6  0.850482 -1.074430  0.792511

# %%
# the same interpolation methods available for reindexing can be used with fillna()
df = pd.DataFrame(np.random.standard_normal((6,3)))
df
# Out:
#           0         1         2
# 0 -0.778042  0.088271  0.860713
# 1  0.000025  0.620280 -0.570208
# 2  1.355648  0.453042 -0.804245
# 3  0.959749  0.647315  0.079205
# 4  0.377750 -1.396355 -1.081522
# 5  0.242886 -0.424465  0.493962

# %%
df.iloc[2:,1] = np.nan
df
# Out:
#           0         1         2
# 0 -0.778042  0.088271  0.860713
# 1  0.000025  0.620280 -0.570208
# 2  1.355648       NaN -0.804245
# 3  0.959749       NaN  0.079205
# 4  0.377750       NaN -1.081522
# 5  0.242886       NaN  0.493962

# %%
df.iloc[4:,2] = np.nan
df
# Out:
#           0         1         2
# 0 -0.778042  0.088271  0.860713
# 1  0.000025  0.620280 -0.570208
# 2  1.355648       NaN -0.804245
# 3  0.959749       NaN  0.079205
# 4  0.377750       NaN       NaN
# 5  0.242886       NaN       NaN

# %%
df.fillna(method="ffill")
# "ffill" means forward fill; as in Excel "Duplicate Down"
# the NaN values are filled with the preceding non-NaN values, however, ffill stops when it hits a new non-NaN value
# opposite of "ffill" is "bfill" (back fill)
# Out:
#           0         1         2
# 0 -0.778042  0.088271  0.860713
# 1  0.000025  0.620280 -0.570208
# 2  1.355648  0.620280 -0.804245
# 3  0.959749  0.620280  0.079205
# 4  0.377750  0.620280  0.079205
# 5  0.242886  0.620280  0.079205

# %%
df.fillna(method="ffill",limit=2)

# "limit = 2" means limit the fill to 2 rows
# Out:
#           0         1         2
# 0 -0.778042  0.088271  0.860713
# 1  0.000025  0.620280 -0.570208
# 2  1.355648  0.620280 -0.804245
# 3  0.959749  0.620280  0.079205
# 4  0.377750       NaN  0.079205
# 5  0.242886       NaN  0.079205

# %%
# with .fillna() simple data imputation using median or mean statistics is available
data = pd.Series([1,np.nan,3.5,np.nan,7])
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.fillna(data.mean())
# fill the NaN values with .mean()
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %%
# .fillna() function arguments
# value : scalar value or dictionary-like object to use to fill missing values
# method : interpolation method - one of "bfill" or "ffill"; default is None
# axis : axis to fill on ("index" or "columns"); default is axis="index"
# limit : for ffill and bfill, maximum number of consecutive periods to fill

# %%
# Data Transformation

# %%
# Removing Duplicates

# %%
# removing duplicate rows
data = pd.DataFrame({"k1":["one","two"]*3 + ["two"],"k2":[1,1,2,3,3,4,4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
# DataFrame .duplicated() method returns a Boolean Series indicating whether each row is a duplicate oe nor
# duplicate means its column values are exactly equal to those in an earlier row
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# relatedly, drop_duplicates() returns a DataFrame with rows where the duplicated array is False filtered out
data.drop_duplicates()

# both methods, .duplicated() and .drop_duplicates() by default consider all of the columns;
# alternatively, can specify any subset of them to detect duplicates
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
# having an additional column of values, and want to filter duplicates based only on the "k1" column
data["v1"] = range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
# set column with subset argument
data.drop_duplicates(subset=["k1"])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
# .duplicated() and .drop_duplicates() by default keep the first observed value combination
# passing keep="last" argument will return the last one
data.drop_duplicates(["k1","k2"],keep="last")
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %%
# Transformming Dta Using a Function or Mapping
# transformation based on the values in an array, Series, or column in a DataFrame
data = pd.DataFrame({"food":["bacon","pulled pork","bacon","pastrami","corned beef","bacon","pastrami","honey ham","nova lox"],
                     "ounces":[4,3,12,6,7.5,8,3,5,6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
# suppose we wanted to add a column indicating the type of animal for each food
meat_to_animal = {
    "bacon": "pig",
    "pulled pork": "pig",
    "pastrami": "cow",
    "corned beef": "cow",
    "honey ham": "pig",
    "nova lox": "salmon"
}

meat_to_animal
# Out:
# {'bacon': 'pig',
#  'pulled pork': 'pig',
#  'pastrami': 'cow',
#  'corned beef': 'cow',
#  'honey ham': 'pig',
#  'nova lox': 'salmon'}

# %%
# .map() method on a Series accepts a function or dictionary-like object containing a mapping
data["animal"] = data["food"].map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
# could also have passed a function that does all the work
def get_animal(x):
    return meat_to_animal[x]

data["food"].map(get_animal)
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: object

# %%
# using .map() is a convenient way to perform element-wise transformatioins and other data cleaning-related operations

# %%
# Replacing Values
# .map() can be used to modify a subset of values in an object,
# but .replace() provides a simpler and more flexible way
data = pd.Series([1.,-999.,2.,-999.,-1000.,3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
# using "-999" values as sentinel values for missing data - replacing those with NA values
data.replace(-999,np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
# replacing multiple values at once - passing a list with substitute values
data.replace([-999,-1000],np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
# replacing different values for each, pass a list of substitutes
data.replace([-999,-1000],[np.nan,0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
# passing argument can also be a dictionary
data.replace({-999:np.nan,-1000:0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
# renaming axis indexes
# axis labels can be similarly transformed by a function or mapping of some form to produce new, differently labeled objects
# modifying the axes in place without creating a new data structure
data = pd.DataFrame(np.arange(12).reshape((3,4)),
        index = ["ohio","Colorado","New York"],
        columns = ["one","two","three","four"])
data
# Out:
#           one  two  three  four
# ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
# .map() method for axis indexes, just like in Series
def transform(x):
    return x[:4].upper()

data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
# can assign to the index attribute, modifying the DataFrame in place
data.index = data.index.map(transform)
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
# if wanting to create a transformed version without modifying the origina, .renam() can be used
data.rename(index=str.title,columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
# .rename() can be used in conjuction with a dictionary-like object
data.rename(index={"OHIO":"INDIANA"},
           columns={"three":"peekaboo"})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11

# %%
# Discretization and Binning
# data about a group of people in a study, gropuping them into discreet age buckets
ages = [20,22,25,27,21,23,37,31,61,45,41,32]
ages
# Out:
# [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
# bins = 18 to 25, 26 to 35, 36 to 60, and 61 and older
# use pd.cut()
bins = [18,25,35,60,100]
age_categories = pd.cute(ages,bins)
age_categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_19336/293240299.py in <module>
#       2 # use pd.cut()
#       3 bins = [18,25,35,60,100]
# ----> 4 age_categories = pd.cute(ages,bins)
#       5 age_categories
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'cute'

# %%
bins = [18,25,35,60,100]
age_categories = pd.cut(ages,bins)
age_categories
# each bin is identified by a special interval value type containing lower and upper limit of each bin
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
# data codified in numberical integers (the "pointer" to the category)
age_categories.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
# index of unique labels created; telling what the buckets are called, the "reference table"
age_categories.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]], dtype='interval[int64, right]')

# %%
age_categories.categories[0]
# Out:
# Interval(18, 25, closed='right')

# %%
# pd.value_counts() are the bin counts for the result of pd.cut()
pd.value_counts(age_categories)
# Out:
# (18, 25]     5
# (25, 35]     3
# (35, 60]     3
# (60, 100]    1
# dtype: int64

# %%
# in the string representation of an interval, a parenthesis means that the side is open (exclusive)
# square bracket means it's closed (inclusive)
# can change which side is closed by passing "right = False"
pd.cut(ages,bins,right=False)
# Out:
# [[18, 25), [18, 25), [25, 35), [25, 35), [18, 25), ..., [25, 35), [60, 100), [35, 60), [35, 60), [25, 35)]
# Length: 12
# Categories (4, interval[int64, left]): [[18, 25) < [25, 35) < [35, 60) < [60, 100)]

# %%
# can overrid the default interval-based bin labeling, by passing a list or arroy to the labels
group_names = ["Youth","YoungAdult","MiddleAged","Senior"]
pd.cut(ages,bins,labels=group_names)
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %%
# passing an integer number of bins to pd.cut() instead of explicit bin edges,
# it will compute equal-length bins based on min and max values
data = np.random.uniform(size=20)
data
# Out:
# array([0.35441359, 0.05901113, 0.49223894, 0.02110399, 0.38046688,
#        0.25221478, 0.44214983, 0.15403294, 0.69643867, 0.05896486,
#        0.90697943, 0.01011503, 0.96387608, 0.54411993, 0.4263027 ,
#        0.55631272, 0.50411895, 0.56332833, 0.71337579, 0.88868687])

# %%
pd.cut(data,4,precision=2)
# Out:
# [(0.25, 0.49], (0.0092, 0.25], (0.49, 0.73], (0.0092, 0.25], (0.25, 0.49], ..., (0.49, 0.73], (0.49, 0.73], (0.49, 0.73], (0.49, 0.73], (0.73, 0.96]]
# Length: 20
# Categories (4, interval[float64, right]): [(0.0092, 0.25] < (0.25, 0.49] < (0.49, 0.73] < (0.73, 0.96]]

# %%
# pd.qcut() bins the data based on sample quantiles
# it will obtain roughly equally sized bins (slicing in quantiles)
data = np.random.standard_normal(1000)
data
# Out:
# array([ 9.67535825e-01, -1.12630325e+00,  7.01682817e-01, -3.40066082e-01,
#        -6.00165875e-01,  9.90571302e-02, -5.67770668e-01,  1.36501012e+00,
#         3.21879843e-01,  1.80632938e+00, -6.72582077e-01,  1.53492832e+00,
#         1.17710257e+00, -1.23493269e+00,  7.91773552e-01,  7.21007637e-01,
#        -1.84489674e+00,  6.22171299e-01, -1.54266356e-01, -6.24962988e-01,
#         3.08774936e-01, -2.18847715e+00,  1.01496867e+00, -2.00155007e+00,
#         4.31830826e-01, -1.88131629e+00,  1.02097250e+00, -1.27877039e-01,
#         1.01898085e+00,  8.02719564e-01, -7.09501176e-01, -4.31488973e-01,
#         1.53663394e-02, -8.47655100e-01,  4.60347094e-02, -9.68733828e-01,
#        -8.58339707e-01,  4.09301246e-01,  4.23737070e-01,  1.48017257e+00,
#         2.16944606e-01, -3.42490044e-01,  6.78092744e-01, -1.53330694e-01,
#        -1.76390995e+00, -1.80514058e-01, -2.61362166e-01, -1.07540905e+00,
#         9.94937941e-03,  7.24078506e-02,  3.04626879e-01,  5.37674758e-01,
#         4.44468319e-01, -1.33201057e+00,  3.77035552e-01,  1.04303455e+00,
#         2.68047098e-02,  2.06698793e-02,  4.00668653e-01, -1.49386224e+00,
#         1.15563871e+00,  6.13669379e-01,  2.52302865e-01, -8.21700081e-01,
#        -5.36332490e-01,  1.07646773e+00,  8.36085475e-01, -9.54825862e-01,
#         2.17814833e-01,  4.55297563e-01, -5.42430583e-01,  2.57109593e+00,
#         2.54745783e-01,  9.06001991e-01, -7.92933959e-02, -8.64470027e-02,
#        -1.48383618e-01, -1.01460964e+00,  1.77579135e-01,  3.72593336e-01,
#        -8.75132991e-01,  8.78606082e-01,  1.80541398e-01, -1.15312314e+00,
#        -8.51015294e-01,  3.07010667e-01,  1.12433598e-01, -8.45577844e-01,
#        -4.01528662e-01,  7.92997382e-01,  1.33874162e+00,  1.03904620e+00,
#        -9.68559635e-01,  3.31474702e-01,  1.88287111e-01, -1.27044675e+00,
#        -1.81436960e+00,  6.96416067e-01,  4.46037247e-02,  1.43827491e+00,
#         3.79698243e-01, -6.13255877e-01, -6.26497547e-01,  4.94736965e-01,
#         8.82608473e-01, -5.71815287e-01,  2.29364359e-01,  2.03722906e+00,
#         1.17000344e+00, -1.64646428e+00,  3.29831891e-02,  9.15844991e-02,
#         2.07990772e+00,  1.30638973e+00,  1.51972888e+00,  1.12727529e-01,
#         1.24479387e-01,  9.19716366e-01,  2.21865640e-02, -2.44093547e-01,
#         2.34176967e-01,  1.37193335e-01,  1.37019025e+00,  9.67681225e-01,
#        -5.65961942e-01, -1.12154072e-01, -1.40754747e-01,  3.92855924e-01,
#        -9.97381218e-02, -4.44312417e-01, -2.81661520e-01, -1.10557688e+00,
#         1.43224722e-01, -5.71605920e-01,  4.81045270e-02, -7.81390137e-01,
#        -2.39646841e-02, -2.83896925e-01,  8.98592255e-01,  1.19578391e+00,
#        -5.23678226e-02, -5.43448684e-01,  4.88653482e-01,  3.77681995e-01,
#         7.96417150e-01,  2.53468319e-01, -6.60022252e-01, -6.60604472e-01])

# %%
quartiles = pd.qcut(data,4,precision=2)
quartiles
# Out:
# [(0.65, 3.33], (-2.8899999999999997, -0.67], (0.65, 3.33], (-0.67, 0.013], (-0.67, 0.013], ..., (0.013, 0.65], (0.65, 3.33], (0.013, 0.65], (-0.67, 0.013], (-0.67, 0.013]]
# Length: 1000
# Categories (4, interval[float64, right]): [(-2.8899999999999997, -0.67] < (-0.67, 0.013] < (0.013, 0.65] < (0.65, 3.33]]

# %%
pd.value_counts(quartiles)
# Out:
# (-2.8899999999999997, -0.67]    250
# (-0.67, 0.013]                  250
# (0.013, 0.65]                   250
# (0.65, 3.33]                    250
# dtype: int64

# %%
# similar to pd.cut(), can pass own quantiles (between 0 and 1, inclusive)
pd.qcut(data,[0,0.1,0.5,0.9,1]).value_counts()
# Out:
# (-2.8819999999999997, -1.235]    100
# (-1.235, 0.0127]                 400
# (0.0127, 1.233]                  400
# (1.233, 3.33]                    100
# dtype: int64
